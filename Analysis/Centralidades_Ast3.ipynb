# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
#Nos conectamos al drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Datos
net_Ast3 = pd.read_csv("/content/drive/My Drive/Sakura/Subnet_SF.csv")
net_Ast3=net_Ast3[['Source','Target']]
net_Ast3.head()
# Out:
#     Source   Target
# 0     ABL1   BCL6AA
# 1    APBB1  NOTCH1B
# 2     ARXA     SHHA
# 3   BCL6AA   BCL6AA
# 4  CRABP2A    RARAB

# %%
len(net_Ast3)
# Out:
# 143

# %%
G = nx.from_pandas_edgelist(net_Ast3, 'Source', 'Target', create_using=nx.DiGraph)

# %%
print(nx.is_directed(G))
# Out:
# True

# %%
# Observamos la información basica del grafo
print('Number of nodes', len(G.nodes))
print('Number of edges', len(G.edges))
# Out:
# Number of nodes 127
# Number of edges 143

# %%
import operator
DegreeCen=nx.degree_centrality(G)
sortedDCen = sorted(DegreeCen.items(), key=operator.itemgetter(1), reverse=True)
for d in sortedDCen[:10]:
    print(d)
# Out:
# ('SOX2', 0.1349206349206349)
# ('MITFB', 0.11904761904761904)
# ('BCL6AA', 0.10317460317460317)
# ('SHHA', 0.10317460317460317)
# ('PAX6A', 0.09523809523809523)
# ('RARAB', 0.07936507936507936)
# ('KITA', 0.06349206349206349)
# ('NOTCH1B', 0.05555555555555555)
# ('ISL1A', 0.05555555555555555)
# ('LHX1A', 0.047619047619047616)

# %%
betweenness_dict = nx.betweenness_centrality(G) # Run betweenness centrality
nx.set_node_attributes(G, betweenness_dict, 'betweenness')

# %%
sorted_betweenness = sorted(betweenness_dict.items(), key=operator.itemgetter(1), reverse=True)

print("Top 20 nodes by betweenness centrality:")
for b in sorted_betweenness[:10]:
    print(b)
# Out:
# Top 20 nodes by betweenness centrality:
# ('PAX6A', 0.01307936507936508)
# ('SOX2', 0.0113015873015873)
# ('MITFB', 0.009333333333333332)
# ('ISL1A', 0.004507936507936508)
# ('POU4F2', 0.0020952380952380953)
# ('PAX2A', 0.0011428571428571427)
# ('PROX1A', 0.0003809523809523809)
# ('LHX1A', 0.00025396825396825396)
# ('PITX3', 0.00019047619047619045)
# ('ABL1', 0.0)

# %%
closeness_dict = nx.closeness_centrality(G)
sorted_closeness = sorted(closeness_dict.items(),key=operator.itemgetter(1), reverse=True)

f = open("closeness_centrality.txt","w")
f.write( str(closeness_dict) )
f.close()

for b in sorted_closeness[:10]:
    print(b)
# Out:
# ('SHHA', 0.17063492063492064)
# ('SOX2', 0.12129827055200189)
# ('NR2E1', 0.11080586080586081)
# ('PAX6A', 0.10381810381810382)
# ('MITFB', 0.10317460317460317)
# ('KITA', 0.10294117647058823)
# ('ISL1A', 0.10250074872716382)
# ('CRYABB', 0.09040178571428571)
# ('POU4F2', 0.08910162002945508)
# ('BCL6AA', 0.0873015873015873)

# %%
closeness_dict = nx.closeness_centrality(G)
sorted_closeness = sorted(closeness_dict.items(),key=operator.itemgetter(1), reverse=True)

f = open("closeness_centrality.txt","w")
f.write( str(closeness_dict) )
f.close()

for b in sorted_closeness[:10]:
    print(b)
# Out:
# ('SHHA', 0.17063492063492064)
# ('SOX2', 0.12129827055200189)
# ('NR2E1', 0.11080586080586081)
# ('PAX6A', 0.10381810381810382)
# ('MITFB', 0.10317460317460317)
# ('KITA', 0.10294117647058823)
# ('ISL1A', 0.10250074872716382)
# ('CRYABB', 0.09040178571428571)
# ('POU4F2', 0.08910162002945508)
# ('BCL6AA', 0.0873015873015873)

# %%
katz_dict = nx.katz_centrality(G)
sorted_katz = sorted(katz_dict.items(),key=operator.itemgetter(1), reverse=True)

f = open("katz_centrality.txt","w")
f.write( str(katz_dict) )
f.close()

for b in sorted_katz[:10]:
    print(b)
# Out:
# ('SHHA', 0.19213204194979178)
# ('SOX2', 0.18453745176914454)
# ('BCL6AA', 0.17720710320248875)
# ('MITFB', 0.174675574154885)
# ('RARAB', 0.1518918036129435)
# ('KITA', 0.1465755904864905)
# ('PAX6A', 0.14191910877660402)
# ('NOTCH1B', 0.1313864101251961)
# ('ISL1A', 0.12613503960970546)
# ('HER6', 0.1215134428903548)

# %%
Pagerank_dict = nx.pagerank(G)
sorted_Pagerank = sorted(Pagerank_dict.items(),key=operator.itemgetter(1), reverse=True)

f = open("pagerank_centrality.txt","w")
f.write( str(Pagerank_dict) )
f.close()

for b in sorted_Pagerank[:10]:
    print(b)
# Out:
# ('BCL6AA', 0.178546363533247)
# ('SOX2', 0.04291091094863993)
# ('SHHA', 0.04074835877387505)
# ('PAX6A', 0.03973307282727464)
# ('ISL1A', 0.03850473338865261)
# ('LHX1A', 0.03391252120485055)
# ('MITFB', 0.03210418193042631)
# ('KITA', 0.031242243841563353)
# ('RARAB', 0.025030834192132843)
# ('NOTCH1B', 0.02072843745136103)
