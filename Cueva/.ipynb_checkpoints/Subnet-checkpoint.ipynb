# %%
import pandas as pd
import os 
os.chdir('C:/Users/Usuario/Desktop/ASTYANAX_EYE/cueva/3_Global')
net=pd.read_csv('Global_net_Pach.csv')

# %%
net.head()
# Out:
#          Source Unnamed: 1        Target Unnamed: 3 Interaction
# 0  KAG9259423.1     NELFCD  KAG9260832.1     CDKN1C           +
# 1  KAG9259423.1     NELFCD  KAG9263822.1     CTNNB1           -
# 2  KAG9259423.1     NELFCD  KAG9267104.1      CCND1           -
# 3  KAG9259435.1    POU3F3B  KAG9265347.1     OTX5-A           -
# 4  KAG9259545.1    SMARCC1  KAG9261394.1      PSAT1           ?

# %%
net = net.drop_duplicates()

# %%
net.shape
# Out:
# (9690, 5)

# %%
os.chdir('C:/Users/Usuario/Desktop/ASTYANAX_EYE/cueva')
visual=pd.read_csv('visual.csv')
visual.head()
# Out:
#   Símbolo Product accesion
# 0   PAX6A     KAG9271990.1
# 1   PAX2A     KAG9267230.1
# 2  POU4F2     KAG9275698.1
# 3  HES1-A     KAG9277258.1
# 4    MITF     KAG9269944.1

# %%
filtered_df = net[net['Target'].isin(visual['Product accesion'])]
print(filtered_df)
# Out:
#             Source    Unnamed: 1        Target Unnamed: 3 Interaction
# 6     KAG9259560.1         TBX20  KAG9265460.1      TBX2B           -
# 39    KAG9259712.1          RBPJ  KAG9277258.1     HES1-A           +
# 219   KAG9259909.1  KAG9259909.1  KAG9275391.1      FGF8A           +
# 236   KAG9259909.1  KAG9259909.1  KAG9277258.1     HES1-A           +
# 244   KAG9259909.1  KAG9259909.1  KAG9278398.1       SHHB           ?
# ...            ...           ...           ...        ...         ...
# 9611  KAG9283514.1          GLI3  KAG9275391.1      FGF8A           ?
# 9614  KAG9283514.1          GLI3  KAG9278398.1       SHHB           -
# 9670  KAG9283545.1        TFAP2A  KAG9281994.1      CRYAB           +
# 9672  KAG9283545.1        TFAP2A  KAG9282763.1       KITA           ?
# 9679  KAG9283657.1         ZFPM2  KAG9266803.1       LHX9           -
#
# [203 rows x 5 columns]

# %%
filtered_df.to_csv('Subnet_Pachon.csv')
