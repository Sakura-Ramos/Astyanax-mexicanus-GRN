# %%
import pandas as pd 
import os

# %%
os.chdir('C:/Users/Usuario/Desktop/ASTYANAX_EYE/Superficie/4_Global')
sf = pd.read_csv('SF_global.csv')

# %%
os.chdir('C:/Users/Usuario/Desktop/ASTYANAX_EYE/cueva/3_Global')
cf = pd.read_csv('CF_global.csv')

# %%
sf.head()
# Out:
#   Source  Target Interaction
# 0   AATF  CDKN1D           ?
# 1   AATF    MYCB           +
# 2   AATF    TP53           ?
# 3   ABL1   BCL2B           -
# 4   ABL1  BCL6AA           -

# %%
sf.shape
# Out:
# (12017, 3)

# %%
cf.head()
# Out:
#   Source  Target Interaction
# 0   AATF  CDKN1A           ?
# 1   AATF    MYCB           +
# 2   AATF    TP53           ?
# 3   ABL1    BCL2           -
# 4   ABL1    BCL6           -

# %%
cf.shape
# Out:
# (5426, 3)

# %%
def resolver_interaccion(grupo):
    # Filtrar interacciones conocidas
    conocidos = grupo[grupo['Interaction'].isin(['+', '-'])]
    if not conocidos.empty:
        return conocidos.iloc[[0]]  # Conserva una interacción conocida
    else:
        return grupo.iloc[[0]]  # Si no hay conocidas, conserva una con '?'

# Aplicar la función agrupando por Source y Target
sf_net = sf.groupby(['Source', 'Target'], group_keys=False).apply(resolver_interaccion).reset_index(drop=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_12884\2462749923.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sf_net = sf.groupby(['Source', 'Target'], group_keys=False).apply(resolver_interaccion).reset_index(drop=True)

# %%
sf_net.shape
# Out:
# (6406, 3)

# %%
def resolver_interaccion(grupo):
    # Filtrar interacciones conocidas
    conocidos = grupo[grupo['Interaction'].isin(['+', '-'])]
    if not conocidos.empty:
        return conocidos.iloc[[0]]  # Conserva una interacción conocida
    else:
        return grupo.iloc[[0]]  # Si no hay conocidas, conserva una con '?'

# Aplicar la función agrupando por Source y Target
cf_net = cf.groupby(['Source', 'Target'], group_keys=False).apply(resolver_interaccion).reset_index(drop=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_12884\3900066579.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   cf_net = cf.groupby(['Source', 'Target'], group_keys=False).apply(resolver_interaccion).reset_index(drop=True)

# %%
cf_net.shape
# Out:
# (5419, 3)

# %%
cf_net.to_csv('Global_CF.csv')

# %%
os.chdir('C:/Users/Usuario/Desktop/ASTYANAX_EYE')
sf = pd.read_csv('Global_SF.csv')

# %%
sf.shape
# Out:
# (6427, 3)

# %%
def resolver_interaccion(grupo):
    # Filtrar interacciones conocidas
    conocidos = grupo[grupo['Interaction'].isin(['+', '-'])]
    if not conocidos.empty:
        return conocidos.iloc[[0]]  # Conserva una interacción conocida
    else:
        return grupo.iloc[[0]]  # Si no hay conocidas, conserva una con '?'

# Aplicar la función agrupando por Source y Target
sf_net = sf.groupby(['Source', 'Target'], group_keys=False).apply(resolver_interaccion).reset_index(drop=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_12884\2462749923.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sf_net = sf.groupby(['Source', 'Target'], group_keys=False).apply(resolver_interaccion).reset_index(drop=True)

# %%
sf_net.shape
# Out:
# (6412, 3)

# %%
sf_net.to_csv('Global_SF.csv')
